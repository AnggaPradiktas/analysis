# %%
import csv
import pandas as pd
import numpy as np
import nltk
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
import re
import seaborn as sns
import matplotlib.pyplot as plt
import base64
import string
from collections import Counter
from nltk.tokenize import word_tokenize
from textblob import TextBlob
from wordcloud import WordCloud
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words

# %%
kompasnews = pd.read_csv("kompasnews.csv")

# %%
kompasnews = kompasnews.drop(columns=['Unnamed: 0'])

# %%
kompasnews = kompasnews[['newstitle']]

# %%
kompasnews
# Out:
#                                              newstitle
# 0    Cegah Banjir di Kota Bima, Normalisasi Sungai ...
# 1    KPK Perpanjang Masa Penahanan 8 Tersangka Kasu...
# 2    2019, Pemerintah Bangun 28,80 Kilometer Jalan ...
# 3    Periksa Irjen PUPR, KPK Telusuri Pemeriksaan I...
# 4    Kasus SPAM PUPR, KPK Panggil Plt Sekjen Cipta ...
# 5    Sistem Penyediaan Air Minum Bandung Raya Siap ...
# 6    Atasi Kemacetan, Depok Ajukan Dana Hibah Rp 6,...
# 7              4 Bendungan Mulai Diisi Air Bulan Depan
# 8    Pekan Depan, Keluar Tarif 7 Ruas Tol Baru Tran...
# 9           Target Sejuta Rumah Tahun Ini 635.361 Unit
# 10   Gunakan Dana SBSN Rp 553,57 Miliar, Jembatan M...
# 11              Jembatan Leta Oar Ralan Siap Berfungsi
# 12   Kasus Proyek Air Minum PUPR, KPK Panggil 2 Pej...
# 13    Kementerian PUPR Batal Bangun Rusun Pasar Minggu
# 14   Dinilai Lebih Berkualitas, Penggunaan Aspal Ka...
# 15   Perubahan Nomenklatur Ditjen Pembiayaan Peruma...
# 16          Politeknik Pekerjaan Umum Siap Dibuka 2019
# 17   Perubahan Nomenklatur, Ditjen Pembiayaan Infra...
# 18   Kaleidoskop 2018: Pecah Telor, Program Sejuta ...
# 19   Sandiaga Uno: Kok Bisa-bisanya Proyek di Lokas...
# 20    Kaleidoskop 2018: Suap di Tubuh Kementerian PUPR
# 21   Kasus Dugaan Suap Proyek Air Minum, KPK Geleda...
# 22     Kementerian PUPR Copot Pejabat yang Dicokok KPK
# 23   Kementerian PUPR Akan Memutus Kontrak Penyuap ...
# 24   Dugaan Suap Proyek Air Minum Kementerian PUPR,...
# 25   5 Fakta Terkait Kasus Dugaan Suap Proyek Air M...
# 26   Pegawainya Tersangka Suap, Kementerian PUPR Ta...
# 27   KPK Tahan 8 Tersangka Dugaan Suap Proyek SPAM ...
# 28   Dugaan Suap di PUPR Terkait Proyek di Daerah B...
# 29         Ini Kronologi OTT Pejabat Kementerian PUPR
# ..                                                 ...
# 506  Menteri PUPR: Tol Suramadu Tak Mungkin Digrati...
# 507  KPK Periksa Dirjen Bina Marga sebagai Saksi Du...
# 508  Kementerian PUPR Tak Jamin Mekanisme BSPS Beba...
# 509  Kata Penyuap Anggota DPR, Ada Aturan Main agar...
# 510  Penyuap Damayanti Disebut Kerap Minta Proyek k...
# 511     Jika Diperlukan, KPK Bisa Periksa Menteri PUPR
# 512  KPK Panggil Kepala BPJN IX Kementerian PUPR Te...
# 513         Damayanti Sebut Nama Yudi Soal Proyek PUPR
# 514  Kementerian PUPR Bantah Bendungan Titab Bali M...
# 515  KPK Geledah Tiga Lokasi Terkait Kasus Suap Pro...
# 516  Kasus Suap Kader PDI-P Diduga Terkait Proyek K...
# 517                Pesan Jokowi untuk Kementerian PUPR
# 518  Jokowi Saksikan Cepatnya Kementerian PUPR Meny...
# 519  Demi Mencapai Target, Kementerian PUPR Percepa...
# 520  Tahun Depan, Kementerian PUPR Prioritaskan Emp...
# 521  Bangun Infrastruktur, JK Ingin Anggaran Kement...
# 522  Menteri PUPR: Kinerja Kabinet Setahun Ini "Roc...
# 523  Konsorsium Asuransi, Penjamin Proyek-proyek Ke...
# 524               Ini Kinerja Setahun Kementerian PUPR
# 525   Serapan Anggaran Kementerian PUPR Baru 33 Persen
# 526  Ini Rencana Kementerian PUPR yang Dinilai Tida...
# 527  Kementerian Pertanian dan Kementerian PUPR Diu...
# 528  Data Tak Jelas, Kementerian PUPR Tinjau Ulang ...
# 529  Anggaran Kementerian PUPR Tahun Depan Rp 103,8...
# 530  Tingkat Serapan Anggaran Kementerian PUPR Baru...
# 531  Atasi Kekeringan, Kementerian PUPR Bangun Sumu...
# 532  Turunkan Harga Barang, Kementerian PUPR Siapka...
# 533  Serapan Anggaran Rendah, Kementerian PUPR Siap...
# 534  Kementerian PUPR Kaji Usulan BKPM Hapus Amdal ...
# 535  Kementerian PUPR Kejar Target Penyerapan 93 Pe...
#
# [536 rows x 1 columns]

# %%
tags_lower = kompasnews['newstitle'].str.lower().str.cat(sep=' ')

# removes punctuation,numbers and returns list of words
tags_remove_pun = re.sub('[^A-Za-z]+', ' ', tags_lower)

# %%
stop_words = list(get_stop_words('id'))         
nltk_words = list(stopwords.words('indonesian'))   
stop_words.extend(nltk_words)

# %%
word_tokens_tags = word_tokenize(tags_remove_pun)
filtered_sentence_tags = [w_tags for w_tags in word_tokens_tags if not w_tags in stop_words]
filtered_sentence_tags = []
for w_tags in word_tokens_tags:
    if w_tags not in stop_words:
        filtered_sentence_tags.append(w_tags)

# %%
without_single_chr_tags = [word_tags for word_tags in filtered_sentence_tags if len(word_tags) > 2]

# %%
import sys
reload(sys)
sys.setdefaultencoding('utf8')

# %%
cleaned_data_tags = [word_tags for word_tags in without_single_chr_tags if not word_tags.isdigit()]

# %%
top_N = 1000

# %%
word_dist_tags = nltk.FreqDist(cleaned_data_tags)
rslt_tags = pd.DataFrame(word_dist_tags.most_common(top_N),
                    columns=['Word', 'Frequency'])

# %%
plt.figure(figsize=(18,10))
sns.set_style("whitegrid")
plt.title('Kompas Topics')

ax = sns.barplot(x="Word",y="Frequency", data=rslt_tags.head(10))

rects = ax.patches

# For each bar: Place a label
for rect in rects:
    # Get X and Y placement of label from rect.
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width() / 2

    # Number of points between bar and label. Change to your liking.
    space = 5
    # Vertical alignment for positive values
    va = 'bottom'

    # If value of bar is negative: Place label below bar
    if y_value < 0:
        # Invert space to place label below
        space *= -1
        # Vertically align label at top
        va = 'top'

    # Use Y value as label and format number with one decimal place
    label = "{:.1f}".format(y_value)

    # Create annotation
    plt.annotate(
        label,                      # Use `label` as label
        (x_value, y_value),         # Place label at end of the bar
        xytext=(0, space),          # Vertically shift label by `space`
        textcoords="offset points", # Interpret `xytext` as offset in points
        ha='center',                # Horizontally center label
        va=va)                      # Vertically align label differently for
                                    # positive and negative values.

# %%
bloblist_desc = list()

train_descr_str=kompasnews['newstitle'].astype(str)
for row in train_descr_str:
    blob = TextBlob(row)
    an = blob.translate(from_lang='id', to='en')
    bloblist_desc.append((row,an.sentiment.polarity, an.sentiment.subjectivity))
    train_polarity_desc = pd.DataFrame(bloblist_desc, columns = ['sentence','sentiment','polarity'])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-17-3a80e604f767> in <module>()
#       4 for row in train_descr_str:
#       5     blob = TextBlob(row)
# ----> 6     an = blob.translate(from_lang='id', to='en')
#       7     bloblist_desc.append((row,an.sentiment.polarity, an.sentiment.subjectivity))
#       8     train_polarity_desc = pd.DataFrame(bloblist_desc, columns = ['sentence','sentiment','polarity'])
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/site-packages/textblob/blob.pyc in translate(self, from_lang, to)
#     545         """
#     546         return self.__class__(self.translator.translate(self.raw,
# --> 547                               from_lang=from_lang, to_lang=to))
#     548
#     549     def detect_language(self):
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/site-packages/textblob/translate.pyc in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
#      53         )
# ---> 54         response = self._request(url, host=host, type_=type_, data=data)
#      55         result = json.loads(response)
#      56         if isinstance(result, list):
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/site-packages/textblob/translate.pyc in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     433         for processor in self.process_response.get(protocol, []):
#     434             meth = getattr(processor, meth_name)
# --> 435             response = meth(req, response)
#     436
#     437         return response
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in http_response(self, request, response)
#     546         if not (200 <= code < 300):
#     547             response = self.parent.error(
# --> 548                 'http', request, response, code, msg, hdrs)
#     549
#     550         return response
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in error(self, proto, *args)
#     465             http_err = 0
#     466         args = (dict, proto, meth_name) + args
# --> 467         result = self._call_chain(*args)
#     468         if result:
#     469             return result
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in http_error_302(self, req, fp, code, msg, headers)
#     652         fp.close()
#     653
# --> 654         return self.parent.open(new, timeout=req.timeout)
#     655
#     656     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     433         for processor in self.process_response.get(protocol, []):
#     434             meth = getattr(processor, meth_name)
# --> 435             response = meth(req, response)
#     436
#     437         return response
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in http_response(self, request, response)
#     546         if not (200 <= code < 300):
#     547             response = self.parent.error(
# --> 548                 'http', request, response, code, msg, hdrs)
#     549
#     550         return response
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in error(self, proto, *args)
#     471         if http_err:
#     472             args = (dict, 'default', 'http_error_default') + orig_args
# --> 473             return self._call_chain(*args)
#     474
#     475 # XXX probably also want an abstract factory that knows when it makes
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in http_error_default(self, req, fp, code, msg, hdrs)
#     554 class HTTPDefaultErrorHandler(BaseHandler):
#     555     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 556         raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
#     557
#     558 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 503: Service Unavailable

# %%
def f(train_polarity_desc):
    if train_polarity_desc['sentiment'] > 0:
        val = "Positive"
    elif train_polarity_desc['sentiment'] == 0:
        val = "Neutral"
    else:
        val = "Negative"
    return val

train_polarity_desc['Sentiment_Type'] = train_polarity_desc.apply(f, axis=1)

plt.figure(figsize=(5,10))
sns.set_style("whitegrid")
plt.title('KompasNews Sentiment')
ax = sns.countplot(x="Sentiment_Type", data=train_polarity_desc, palette=["C0", "C1", "k"])

# %%
train_polarity_desc
# Out:
#                                               sentence  sentiment  polarity  \
# 0    Cegah Banjir di Kota Bima, Normalisasi Sungai ...   0.000000  0.000000
# 1    KPK Perpanjang Masa Penahanan 8 Tersangka Kasu...   0.000000  0.000000
# 2    2019, Pemerintah Bangun 28,80 Kilometer Jalan ...   0.000000  0.000000
# 3    Periksa Irjen PUPR, KPK Telusuri Pemeriksaan I...   0.025000  0.250000
# 4    Kasus SPAM PUPR, KPK Panggil Plt Sekjen Cipta ...   0.000000  0.000000
# 5    Sistem Penyediaan Air Minum Bandung Raya Siap ...   0.350000  0.500000
# 6    Atasi Kemacetan, Depok Ajukan Dana Hibah Rp 6,...   0.000000  0.000000
# 7              4 Bendungan Mulai Diisi Air Bulan Depan   0.000000  0.000000
# 8    Pekan Depan, Keluar Tarif 7 Ruas Tol Baru Tran...   0.068182  0.227273
# 9           Target Sejuta Rumah Tahun Ini 635.361 Unit   0.000000  0.000000
# 10   Gunakan Dana SBSN Rp 553,57 Miliar, Jembatan M...   0.000000  0.000000
# 11              Jembatan Leta Oar Ralan Siap Berfungsi   0.200000  0.500000
# 12   Kasus Proyek Air Minum PUPR, KPK Panggil 2 Pej...   0.000000  0.000000
# 13    Kementerian PUPR Batal Bangun Rusun Pasar Minggu   0.000000  0.000000
# 14   Dinilai Lebih Berkualitas, Penggunaan Aspal Ka...   0.500000  0.500000
# 15   Perubahan Nomenklatur Ditjen Pembiayaan Peruma...   0.167857  0.517857
# 16          Politeknik Pekerjaan Umum Siap Dibuka 2019   0.066667  0.355556
# 17   Perubahan Nomenklatur, Ditjen Pembiayaan Infra...   0.050000  0.500000
# 18   Kaleidoskop 2018: Pecah Telor, Program Sejuta ...   0.000000  0.000000
# 19   Sandiaga Uno: Kok Bisa-bisanya Proyek di Lokas...   0.000000  0.000000
# 20    Kaleidoskop 2018: Suap di Tubuh Kementerian PUPR   0.000000  0.000000
# 21   Kasus Dugaan Suap Proyek Air Minum, KPK Geleda...  -0.100000  0.100000
# 22     Kementerian PUPR Copot Pejabat yang Dicokok KPK   0.000000  0.000000
# 23   Kementerian PUPR Akan Memutus Kontrak Penyuap ...   0.000000  0.000000
# 24   Dugaan Suap Proyek Air Minum Kementerian PUPR,...  -0.100000  0.100000
# 25   5 Fakta Terkait Kasus Dugaan Suap Proyek Air M...  -0.100000  0.100000
# 26   Pegawainya Tersangka Suap, Kementerian PUPR Ta...   0.000000  0.000000
# 27   KPK Tahan 8 Tersangka Dugaan Suap Proyek SPAM ...   0.000000  0.000000
# 28   Dugaan Suap di PUPR Terkait Proyek di Daerah B...  -0.100000  0.100000
# 29         Ini Kronologi OTT Pejabat Kementerian PUPR    0.000000  0.000000
# ..                                                 ...        ...       ...
# 391  Kementerian PUPR Gelar Edukasi Publik Penataan...   0.000000  0.066667
# 392  Kementerian PUPR Edukasi Publik Soal Penataan ...   0.000000  0.066667
# 393  Menteri PUPR: Masa Cuma Bikin Bendungan 7 Tahu...   0.400000  0.800000
# 394             Kapolri Teken MoU dengan Tujuh Lembaga   0.000000  0.000000
# 395  KPK Perpanjang Masa Penahanan Politisi PKB Mus...   0.000000  0.000000
# 396  Ganti Heli setelah Mendarat Darurat, Menteri P...   0.000000  0.000000
# 397  Pilot Kena Serangan Jantung, Heli Berpenumpang...   0.000000  0.000000
# 398  Djarot: Rusun Jatinegara Bocor Dibangun Kement...  -0.025000  0.125000
# 399  Pejabat PUPR Terbukti Gunakan Suap untuk Kampa...   0.000000  0.000000
# 400        Mantan Pejabat PUPR Divonis 6 Tahun Penjara   0.000000  0.000000
# 401  Hari Air Dunia, Kementerian PUPR Ajak Komunita...   0.000000  0.000000
# 402  Bacakan Nota Pembelaan, Mantan Pejabat PUPR Me...  -0.100000  0.300000
# 403  Peringati Hari Air Dunia, Kementerian PUPR Gan...   0.000000  0.000000
# 404  Kementerian PUPR Dapat Empat PR Baru Siapkan I...   0.068182  0.227273
# 405  Anggaran Infrastruktur Tiap Ditjen di Kementer...   0.000000  0.000000
# 406  Mantan Kepala BPJN Maluku Ditanya Pemberian Ua...   0.000000  0.000000
# 407  Kementerian PUPR Studi Revitalisasi Danau Laut...   0.000000  0.000000
# 408  Pusat Pengendalian Lumpur Sidoarjo Masuk Struk...  -0.100000  0.100000
# 409  Kadis PUPR Kupang: Lahan "Resettlement" Eks Ti...   0.000000  0.000000
# 410  Dugaan Suap di Kementerian PUPR, KPK Periksa M...  -0.100000  0.100000
# 411  Dukung Perkembangan Irigasi, Kementerian PUPR ...   0.000000  0.000000
# 412  Kementerian PUPR Kaji Dampak MRT dan LRT Terha...   0.000000  0.000000
# 413  KPK Kembali Periksa Politisi PKB dan Pejabat K...   0.000000  0.000000
# 414  Kasus Suap Kementerian PUPR, KPK Tahan Komisar...   0.000000  0.000000
# 415  Temui Dubes Perancis, Basuki Bahas Kerja Sama ...   0.000000  0.000000
# 416  Ditjen SDA Kementerian PUPR Resmikan Program J...   0.016667  0.211111
# 417  Pencalonan Pejabat di Kementerian PUPR, Amran ...   0.000000  0.000000
# 418  Maurin Pensiun, Syarif Burhanuddin Plt Dirjen ...   0.025000  0.250000
# 419  KPK "Ancam" Jemput Paksa Bupati Halmahera Timu...  -0.300000  0.200000
# 420  Kasus Suap Proyek Kementerian PUPR, KPK Periks...   0.000000  0.000000
#
#     Sentiment_Type
# 0          Neutral
# 1          Neutral
# 2          Neutral
# 3         Positive
# 4          Neutral
# 5         Positive
# 6          Neutral
# 7          Neutral
# 8         Positive
# 9          Neutral
# 10         Neutral
# 11        Positive
# 12         Neutral
# 13         Neutral
# 14        Positive
# 15        Positive
# 16        Positive
# 17        Positive
# 18         Neutral
# 19         Neutral
# 20         Neutral
# 21        Negative
# 22         Neutral
# 23         Neutral
# 24        Negative
# 25        Negative
# 26         Neutral
# 27         Neutral
# 28        Negative
# 29         Neutral
# ..             ...
# 391        Neutral
# 392        Neutral
# 393       Positive
# 394        Neutral
# 395        Neutral
# 396        Neutral
# 397        Neutral
# 398       Negative
# 399        Neutral
# 400        Neutral
# 401        Neutral
# 402       Negative
# 403        Neutral
# 404       Positive
# 405        Neutral
# 406        Neutral
# 407        Neutral
# 408       Negative
# 409        Neutral
# 410       Negative
# 411        Neutral
# 412        Neutral
# 413        Neutral
# 414        Neutral
# 415        Neutral
# 416       Positive
# 417        Neutral
# 418       Positive
# 419       Negative
# 420        Neutral
#
# [421 rows x 4 columns]
