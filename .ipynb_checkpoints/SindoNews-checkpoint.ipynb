# 397  Sekretaris Jenderal Kementerian Pekerjaan Umum...
# 398  Kementerian PUPR pernah didatangi beberapa pel...
# 399  Ditjen Bina Marga Kementerian Pekerjaan Umum d...
# 400  Kementerian PUPR mengklaim hingga saat ini tel...
# 401  Pemerintah melalui Direktorat Jenderal Penyedi...
# 402  Kementerian PUPR mendapatkan kucuran anggaran ...
# 403  Kementerian Pekerjaan Umum dan Perumahan Rakya...
# 404  Direktorat Jenderal Sumber Daya Air (SDA) Keme...
# 405  Kementerian PUPR akan memberdayakan pemerintah...
# 406  Kementerian Pekerjaan Umum dan Perumahan Rakya...
# 407  Kementerian Pekerjaan Umum dan Perumahan Rakya...
# 408  Kementerian PUPR bersama pengembang berencana ...
# 409  Kementerian PUPR menyatakan, hingga Juli 2015 ...
# 410  Kementerian PUPR mengaku sudah melakukan persi...
# 411  Jasa Marga sudah mengajukan surat resmi kepada...
# 412  Kementerian Pekerjaan Umum dan Perumahan Rakya...
# 413  Sabtu, 13 Juni, Presiden Joko Widodo (Jokowi) ...
# 414  Pemerintah mempertimbangkan pembangunan jalur ...
# 415  Ratusan kilometer jalan nasional di Banten mas...
# 416  Kementerian Pekerjaan Umum dan Perumahan Rakya...
# 417  Presiden Jokowi didampingi Menteri PUPR Basuki...
# 418  Kementerian PURR mengusulkan dana sebesar Rp12...
# 419  Kementerian PURR bertekad mengembalikan identi...
#
# [420 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import base64
import string
from collections import Counter
from nltk.tokenize import word_tokenize
from textblob import TextBlob

# %%
from wordcloud import WordCloud
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS

# %%
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words

# %%
tags_lower = train['News Title'].str.lower().str.cat(sep=' ')

# removes punctuation,numbers and returns list of words
tags_remove_pun = re.sub('[^A-Za-z]+', ' ', tags_lower)

# %%
stop_words = list(get_stop_words('id'))         
nltk_words = list(stopwords.words('indonesian'))   
stop_words.extend(nltk_words)

# %%
word_tokens_tags = word_tokenize(tags_remove_pun)
filtered_sentence_tags = [w_tags for w_tags in word_tokens_tags if not w_tags in stop_words]
filtered_sentence_tags = []
for w_tags in word_tokens_tags:
    if w_tags not in stop_words:
        filtered_sentence_tags.append(w_tags)

# %%
without_single_chr_tags = [word_tags for word_tags in filtered_sentence_tags if len(word_tags) > 2]

# %%
cleaned_data_tags = [word_tags for word_tags in without_single_chr_tags if not word_tags.isnumeric()]

# %%
top_N = 10000

# %%
word_dist_tags = nltk.FreqDist(cleaned_data_tags)
rslt_tags = pd.DataFrame(word_dist_tags.most_common(top_N),
                    columns=['Word', 'Frequency'])

# %%
plt.figure(figsize=(18,10))
sns.set_style("whitegrid")
plt.title('SindoNews Topics')
ax = sns.barplot(x="Word",y="Frequency", data=rslt_tags.head(10))

rects = ax.patches
# For each bar: Place a label
for rect in rects:
    # Get X and Y placement of label from rect.
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width() / 2

    # Number of points between bar and label. Change to your liking.
    space = 5
    # Vertical alignment for positive values
    va = 'bottom'

    # If value of bar is negative: Place label below bar
    if y_value < 0:
        # Invert space to place label below
        space *= -1
        # Vertically align label at top
        va = 'top'

    # Use Y value as label and format number with one decimal place
    label = "{:.1f}".format(y_value)

    # Create annotation
    plt.annotate(
        label,                      # Use `label` as label
        (x_value, y_value),         # Place label at end of the bar
        xytext=(0, space),          # Vertically shift label by `space`
        textcoords="offset points", # Interpret `xytext` as offset in points
        ha='center',                # Horizontally center label
        va=va)                      # Vertically align label differently for
                                    # positive and negative values.

# %%
bloblist_desc = list()

train_descr_str=train['News Title'].astype(str)
for row in train_descr_str:
    blob = TextBlob(row)
    an = blob.translate(from_lang='id', to='en')
    bloblist_desc.append((row,an.sentiment.polarity, an.sentiment.subjectivity))
    train_polarity_desc = pd.DataFrame(bloblist_desc, columns = ['sentence','sentiment','polarity'])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-36-206b63f5bf87> in <module>()
#       4 for row in train_descr_str:
#       5     blob = TextBlob(row)
# ----> 6     an = blob.translate(from_lang='id', to='en')
#       7     bloblist_desc.append((row,an.sentiment.polarity, an.sentiment.subjectivity))
#       8     train_polarity_desc = pd.DataFrame(bloblist_desc, columns = ['sentence','sentiment','polarity'])
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/site-packages/textblob/blob.pyc in translate(self, from_lang, to)
#     545         """
#     546         return self.__class__(self.translator.translate(self.raw,
# --> 547                               from_lang=from_lang, to_lang=to))
#     548
#     549     def detect_language(self):
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/site-packages/textblob/translate.pyc in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
#      53         )
# ---> 54         response = self._request(url, host=host, type_=type_, data=data)
#      55         result = json.loads(response)
#      56         if isinstance(result, list):
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/site-packages/textblob/translate.pyc in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     433         for processor in self.process_response.get(protocol, []):
#     434             meth = getattr(processor, meth_name)
# --> 435             response = meth(req, response)
#     436
#     437         return response
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in http_response(self, request, response)
#     546         if not (200 <= code < 300):
#     547             response = self.parent.error(
# --> 548                 'http', request, response, code, msg, hdrs)
#     549
#     550         return response
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in error(self, proto, *args)
#     465             http_err = 0
#     466         args = (dict, proto, meth_name) + args
# --> 467         result = self._call_chain(*args)
#     468         if result:
#     469             return result
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in http_error_302(self, req, fp, code, msg, headers)
#     652         fp.close()
#     653
# --> 654         return self.parent.open(new, timeout=req.timeout)
#     655
#     656     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     433         for processor in self.process_response.get(protocol, []):
#     434             meth = getattr(processor, meth_name)
# --> 435             response = meth(req, response)
#     436
#     437         return response
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in http_response(self, request, response)
#     546         if not (200 <= code < 300):
#     547             response = self.parent.error(
# --> 548                 'http', request, response, code, msg, hdrs)
#     549
#     550         return response
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in error(self, proto, *args)
#     471         if http_err:
#     472             args = (dict, 'default', 'http_error_default') + orig_args
# --> 473             return self._call_chain(*args)
#     474
#     475 # XXX probably also want an abstract factory that knows when it makes
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# /Users/anggapradiktas/anaconda3/lib/python2.7/urllib2.pyc in http_error_default(self, req, fp, code, msg, hdrs)
#     554 class HTTPDefaultErrorHandler(BaseHandler):
#     555     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 556         raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
#     557
#     558 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 503: Service Unavailable

# %%
 
def f(train_polarity_desc):
    if train_polarity_desc['sentiment'] > 0:
        val = "Positive"
    elif train_polarity_desc['sentiment'] == 0:
        val = "Neutral"
    else:
        val = "Negative"
    return val

train_polarity_desc['Sentiment_Type'] = train_polarity_desc.apply(f, axis=1)

plt.figure(figsize=(5,10))
sns.set_style("whitegrid")
plt.title('SindoNews Sentiment')
ax = sns.countplot(x="Sentiment_Type", data=train_polarity_desc, palette=["C0", "C1", "k"])

# %%
bloblist_desc = list()
from translate import Translator
translator= Translator(from_lang="id", to_lang="en")

# %%
train_descr_str=train['News Title'].astype(str)
for row in train_descr_str:
    an = translator.translate(row)
    blob = TextBlob(an)
    bloblist_desc.append((row,blob.sentiment.polarity, blob.sentiment.subjectivity))
    train_polarity_desc = pd.DataFrame(bloblist_desc, columns = ['sentence','sentiment','polarity'])

# %%
 
def f(train_polarity_desc):
    if train_polarity_desc['sentiment'] > 0:
        val = "Positive"
    elif train_polarity_desc['sentiment'] == 0:
        val = "Neutral"
    else:
        val = "Negative"
    return val

train_polarity_desc['Sentiment_Type'] = train_polarity_desc.apply(f, axis=1)

plt.figure(figsize=(5,10))
sns.set_style("whitegrid")
plt.title('Sindo Sentiment')
ax = sns.countplot(x="Sentiment_Type", data=train_polarity_desc, palette=["C0", "C1", "k"])

rects = ax.patches

for rect in rects:
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width() / 2
    
    space = 5
    
    va = 'bottom'
    
    label = '{:.1f}'.format(y_value)
    
    plt.annotate(
        label,
        (x_value, y_value),
        xytext=(0, space),
        textcoords='offset points',
        ha = 'center',
        va=va)

# %%
train_polarity_desc
# Out:
#                                               sentence  sentiment  polarity  \
# 0    Jalan Longsor, Dinas PUPR Muba Membuat Konstru...   0.000000  0.000000
# 1    Menkeu Sebut Kementerian Agama Miliki Anggaran...   0.000000  0.000000
# 2    Dalami Suap di KemenPUPR, KPK Periksa Eks Dirj...   0.050000  0.500000
# 3    KPK Indentifikasi 20 Proyek KemenPUPR Didapati...   0.000000  0.000000
# 4    Pemerintah Dituding Lamban Tangani Longsor Sib...  -0.300000  0.400000
# 5                Menangani Korupsi Proyek Bencana Alam   0.100000  0.400000
# 6    KPK Sita Dokumen 12 Proyek Anggaran Rp500 M di...   0.000000  0.000000
# 7    Kasus Suap KemenPUPR, Tiga Lokasi Digeledah da...   0.000000  0.000000
# 8    Usut Korupsi Kementerian PUPR, KPK Temukan Pro...  -0.125000  0.375000
# 9    Geledah Ditjen Cipta Karya, KPK Sita Uang Rp80...   0.025000  0.300000
# 10   OTT PUPR: Lolos Pidana Mati, Tersangka Teranca...  -0.400000  0.550000
# 11   Menteri PUPR: Infrastruktur Kerakyatan Tetap M...   0.600000  0.900000
# 12   Tim Prabowo-Sandi Sebut Korupsi di Kementerian...   0.000000  0.000000
# 13           Ini Kronologi OTT Suap Pejabat Kemen PUPR   0.000000  0.000000
# 14   KPK Tetapkan 8 Tersangka Kasus Dugaan Suap Pej...   0.000000  0.000000
# 15   OTT Pejabat Kemen PUPR, KPK: Proyek SPAM Diang...   0.000000  0.000000
# 16   Hampir 1 Jam Menunggu, Irjen Kemen PUPR Tunggu...   0.075000  0.450000
# 17   OTT Pejabat Kementerian PUPR Diduga Terkait Pr...   0.000000  0.233333
# 18   Respons Menteri PUPR Sikapo Pejabat Ditjen Cip...   0.012500  0.183333
# 19   KPK OTT Pejabat Kementerian PUPR, 10 Orang Dia...   0.000000  0.000000
# 20    Mengkaji Syarat Ambil KPR Tak Pakai Batasan Gaji   0.000000  0.000000
# 21   PUPR Tingkatkan Peran 25 Bank Pelaksana Kredit...   0.000000  0.000000
# 22   Bangun Infrastruktur Pakai Duit SBSN, PUPR Dip...   0.000000  0.000000
# 23   KPK Tetapkan Tersangka Baru Kasus Suap Bupati ...   0.136364  0.454545
# 24                     Kaum Milenial Dapat Subsidi KPR   0.000000  0.000000
# 25   Atasi Banjir Rob Jakarta, Giant Sea Wall Dikem...   0.050000  0.650000
# 26   Konsep Rest Area TOD Tinggal Menunggu Izin Kem...   0.000000  0.000000
# 27   Program IBM Kementerian PUPR Menjangkau hingga...   0.000000  0.000000
# 28   Tak Semua Daerah Pembangunan Infrastruktur di ...   0.000000  0.000000
# 29   PUPR: Pekerja Tak Takut Membangun Infrastruktu...   0.300000  0.900000
# ..                                                 ...        ...       ...
# 390                           Izin Perumahan Dipangkas   0.340000  0.420000
# 391  Kementerian PUPR Sudah Serap Anggaran Rp39,7 T...   0.340000  0.420000
# 392  Kementerian PUPR Klaim Paket Lelang Fisik Suda...   0.340000  0.420000
# 393         WIKA Rampungkan Pembangunan Waduk Jatigede   0.340000  0.420000
