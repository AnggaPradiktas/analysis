# %%
import csv
import pandas as pd
import numpy as np
import nltk
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
import re
import seaborn as sns
import matplotlib.pyplot as plt
import base64
import string
from collections import Counter
from nltk.tokenize import word_tokenize
from textblob import TextBlob
from wordcloud import WordCloud
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words

# %%
train = pd.read_csv('tribunnews.csv', encoding= 'utf8', sep=';')

# %%
train = train[['Fbo', 'Grey2pt5']]

# %%
train
# Out:
#                                                    Fbo  \
# 0    20 Proyek Terindikasi Korupsi, Kementerian PUP...
# 1    KPK Periksa 6 Saksi Kasus Korupsi Penyediaan A...
# 2    KPK Temukan Bukti Baru dalam Kasus Suap Proyek...
# 3    KPK Periksa Direktur Pengembangan SPAM Kemente...
# 4    KPK Memperpanjang Masa Penahanan Tersangka Sua...
# 5    Suap Berjamaah Proyek Air Minum Kementerian PU...
# 6    KPK Dalami Aliran Duit Suap Proyek Penyediaan ...
# 7    Kasus Korupsi SPAM Kementerian PUPR, KPK Perik...
# 8    KPK Periksa Bendahara Satker Satuan Tanggap Da...
# 9    Ketua DPR Ingatkan Kementerian PUPR: Jalan Men...
# 10   Kawasan Dermaga Tawiri Ditata Ulang untuk Akom...
# 11   Direktur Utama PT WKE Naik Kursi Roda Ketika H...
# 12   KPK Bidik Pejabat PPK Lain Terkait Suap SPAM PUPR
# 13   Kasus Korupsi Proyek Air Minum Kementerian PUP...
# 14   KPK Sita Deposito Bernilai Rp 1 Miliar Dari Ru...
# 15   KPK Geledah Tiga Rumah Tersangka Kasus Suap Pr...
# 16   Korupsi Proyek Air Minum Korban Tsunami di Kem...
# 17   Penyidik KPK Bawa 3 Kotak Kontainer Plastik da...
# 18   KPK Amankan CCTV dan Uang Rp 800 Juta dari Kan...
# 19   KPK Geledah Kantor Satker Tanggap Darurat Keme...
# 20   Mobil Penyidik Terparkir di Wisma Sanita, KPK ...
# 21   Komentari Pelaku Korupsi Dana Bencana, Iwan Fa...
# 22   KPK Kecam Keras Proyek Air Minum Korban Tsunam...
# 23   KPK Sita Satu Mobil CRV di Rumah Tersangka Kor...
# 24   KPK Tetapkan 8 Tersangka Kasus Suap Pembanguna...
# 25   KPK Masih Periksa Intensif 20 Orang Hasil Tang...
# 26   Anak Buahnya Kena Operasi Tangkap Tangan KPK, ...
# 27   4 Fakta OTT KPK di Kementerian PUPR, Penjelasa...
# 28      Ditemani Seorang Staf, Irjen PUPR Sambangi KPK
# 29   Fakta-fakta OTT KPK di Kementerian PUPR, 20 Or...
# ..                                                 ...
# 267  Basuki: Persatuan Insinyur Indonesia Jadi Reka...
# 268  Menteri PUPR: Bayar Tol Non Tunai Hanya Butuh ...
# 269  PPDPP Perkuat Koordinasi dengan Ditjen Pembiay...
# 270  Guna Jamin Keselamatan Pengguna Jalan, Kemente...
# 271  Jelang Asian Games XVIII, Rumput Lapangan Sepa...
# 272  Masyarakat Diimbau Berhati-Hati Terhadap Tawar...
# 23   KPK Sita Satu Mobil CRV di Rumah Tersangka Kor...
# 24   KPK Tetapkan 8 Tersangka Kasus Suap Pembanguna...
# 25   KPK Masih Periksa Intensif 20 Orang Hasil Tang...
# 26   Anak Buahnya Kena Operasi Tangkap Tangan KPK, ...
# 27   4 Fakta OTT KPK di Kementerian PUPR, Penjelasa...
# 28   Ditemani Seorang Staf, Irjen PUPR Sambangi KPK...
# 29   Fakta-fakta OTT KPK di Kementerian PUPR, 20 Or...
# ..                                                 ...
# 267  Basuki: Persatuan Insinyur Indonesia Jadi Reka...
# 268  Menteri PUPR: Bayar Tol Non Tunai Hanya Butuh ...
# 269  PPDPP Perkuat Koordinasi dengan Ditjen Pembiay...
# 270  Guna Jamin Keselamatan Pengguna Jalan, Kemente...
# 271  Jelang Asian Games XVIII, Rumput Lapangan Sepa...
# 272  Masyarakat Diimbau Berhati-Hati Terhadap Tawar...
# 273  Perizinan dan Ketersediaan Lahan Jadi Kendala ...
# 274  Tanggapan Kementerian PUPR tentang Rumah DP No...
# 275  Kementerian PUPR Akan Bangun Rumah di Sisa Lah...
# 276  Jelang Asian Games XVIII, Penataan Kawasan GBK...
# 277  Kementerian PUPR: Bank Tanah Dapat Tekan Harga...
# 278  Korban Longsor Luwu Timur Terima Bantuan Mobil...
# 279  Percepat Pertumbuhan Ekonomi, Kementerian PUPR...
# 280  Kementerian PUPR Mulai Bangun Jembatan Ngadilu...
# 281  Pejabat Kementerian PUPR Divonis 6 Tahun dan D...
# 282  Mengaku Bersalah, Terdakwa Amran HI Mustary Me...
# 283  Jembatan Cisomang Dibuka Lagi Mulai 1 April, J...
# 284  Terhitung 1 April Jembatan Cisomang Bisa Dilal...
# 285  DPR Minta Kementerian PUPR Ganti Rugi Lahan Wa...
# 286  Suap Proyek Jalan PUPR, KPK Selidiki Pengemban...
# 287  Pembangunan Jalan di Papua Untuk Membuka Keter...
# 288  Selidiki Kasus Korupsi PUPR, KPK Sudah Periksa...
# 289  Musa Zainuddin Jadi Tahanan KPK Penahanan dila...
# 290  Musa Zainuddin Tersangka Kasus Suap Proyek Jal...
# 291  Kembalikan Uang ke KPK Tapi Mengaku Tidak Mene...
# 292  Menkeu Sri Mulyani Terpesona Keindahan Pemanda...
# 293  Penataan 11 Kawasan Akan Menjadi Contoh Pemben...
# 294  Mau Punya Rumah tapi Penghasilan Rp 4 Juta, In...
# 295  Suap Proyek PUPR, KPK Periksa 7 Saksi Termasuk...
# 296  Wali Kota Surakarta Tinjau Lokasi Rencana Pemb...
#
# [297 rows x 3 columns]

# %%
tags_lower = train['titledesc'].str.lower().str.cat(sep=' ')

# removes punctuation,numbers and returns list of words
tags_remove_pun = re.sub('[^A-Za-z]+', ' ', tags_lower)

# %%
stop_words = list(get_stop_words('id'))         
nltk_words = list(stopwords.words('indonesian'))   
stop_words.extend(nltk_words)

# %%
word_tokens_tags = word_tokenize(tags_remove_pun)
filtered_sentence_tags = [w_tags for w_tags in word_tokens_tags if not w_tags in stop_words]
filtered_sentence_tags = []
for w_tags in word_tokens_tags:
    if w_tags not in stop_words:
        filtered_sentence_tags.append(w_tags)

# %%
without_single_chr_tags = [word_tags for word_tags in filtered_sentence_tags if len(word_tags) > 2]

# %%
cleaned_data_tags = [word_tags for word_tags in without_single_chr_tags if not word_tags.isnumeric()]

# %%
top_N = 10000

# %%
word_dist_tags = nltk.FreqDist(cleaned_data_tags)
rslt_tags = pd.DataFrame(word_dist_tags.most_common(top_N),
                    columns=['Word', 'Frequency'])

# %%
plt.figure(figsize=(18,10))
sns.set_style("whitegrid")
plt.title('TribunNews Topics')
ax = sns.barplot(x="Word",y="Frequency", data=rslt_tags.head(10))


rects = ax.patches

# For each bar: Place a label
for rect in rects:
    # Get X and Y placement of label from rect.
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width() / 2

    # Number of points between bar and label. Change to your liking.
    space = 5
    # Vertical alignment for positive values
    va = 'bottom'

    # If value of bar is negative: Place label below bar
    if y_value < 0:
        # Invert space to place label below
        space *= -1
        # Vertically align label at top
        va = 'top'

    # Use Y value as label and format number with one decimal place
    label = "{:.1f}".format(y_value)

    # Create annotation
    plt.annotate(
        label,                      # Use `label` as label
        (x_value, y_value),         # Place label at end of the bar
        xytext=(0, space),          # Vertically shift label by `space`
        textcoords="offset points", # Interpret `xytext` as offset in points
        ha='center',                # Horizontally center label
        va=va)                      # Vertically align label differently for
                                    # positive and negative values.

# %%
import sys
reload(sys)
sys.setdefaultencoding('utf8')

# %%
bloblist_desc = list()

train_descr_str=train['titledesc'].astype(str)
for row in train_descr_str:
    blob = TextBlob(row)
    an = blob.translate(from_lang='id', to='en')
    bloblist_desc.append((row,an.sentiment.polarity, an.sentiment.subjectivity))
    train_polarity_desc = pd.DataFrame(bloblist_desc, columns = ['sentence','sentiment','polarity'])

# %%
 
def f(train_polarity_desc):
    if train_polarity_desc['sentiment'] > 0:
        val = "Positive"
    elif train_polarity_desc['sentiment'] == 0:
        val = "Neutral"
    else:
        val = "Negative"
    return val

train_polarity_desc['Sentiment_Type'] = train_polarity_desc.apply(f, axis=1)

plt.figure(figsize=(5,10))
sns.set_style("whitegrid")
plt.title('TribunNews Sentiment')
ax = sns.countplot(x="Sentiment_Type", data=train_polarity_desc, palette=["C0", "C1", "k"])

# %%
len(cleaned_data_tags)
# Out:
# 5552

# %%
train_polarity_desc
# Out:
#                                               sentence  sentiment  polarity  \
# 0    20 Proyek Terindikasi Korupsi, Kementerian PUP...   0.122857  0.275238
# 1    KPK Periksa 6 Saksi Kasus Korupsi Penyediaan A...   0.000000  0.600000
# 2    KPK Temukan Bukti Baru dalam Kasus Suap Proyek...   0.007273  0.217576
# 3    KPK Periksa Direktur Pengembangan SPAM Kemente...  -0.033333  0.077778
# 4    KPK Memperpanjang Masa Penahanan Tersangka Sua...  -0.041667  0.291667
# 5    Suap Berjamaah Proyek Air Minum Kementerian PU...   0.050000  0.500000
# 276  Jelang Asian Games XVIII, Penataan Kawasan GBK...   0.000000  0.000000
# 277  Kementerian PUPR: Bank Tanah Dapat Tekan Harga...  -0.500000  0.700000
# 278  Korban Longsor Luwu Timur Terima Bantuan Mobil...   0.033333  0.177778
# 279  Percepat Pertumbuhan Ekonomi, Kementerian PUPR...   0.200000  0.200000
# 280  Kementerian PUPR Mulai Bangun Jembatan Ngadilu...   0.000000  0.066667
# 281  Pejabat Kementerian PUPR Divonis 6 Tahun dan D...   0.500000  1.000000
# 282  Mengaku Bersalah, Terdakwa Amran HI Mustary Me...  -0.200000  0.600000
# 283  Jembatan Cisomang Dibuka Lagi Mulai 1 April, J...   0.000000  0.000000
# 284  Terhitung 1 April Jembatan Cisomang Bisa Dilal...   0.000000  0.066667
# 285  DPR Minta Kementerian PUPR Ganti Rugi Lahan Wa...   0.000000  0.000000
# 286  Suap Proyek Jalan PUPR, KPK Selidiki Pengemban...  -0.041667  0.169444
# 287  Pembangunan Jalan di Papua Untuk Membuka Keter...  -0.025000  0.450000
# 288  Selidiki Kasus Korupsi PUPR, KPK Sudah Periksa...  -0.125000  0.375000
# 289  Musa Zainuddin Jadi Tahanan KPK Penahanan dila...   0.250000  0.333333
# 290  Musa Zainuddin Tersangka Kasus Suap Proyek Jal...   0.000000  0.000000
# 291  Kembalikan Uang ke KPK Tapi Mengaku Tidak Mene...   0.000000  0.000000
# 292  Menkeu Sri Mulyani Terpesona Keindahan Pemanda...   0.100000  0.400000
# 293  Penataan 11 Kawasan Akan Menjadi Contoh Pemben...   0.250000  0.750000
# 294  Mau Punya Rumah tapi Penghasilan Rp 4 Juta, In...   0.000000  0.066667
# 295  Suap Proyek PUPR, KPK Periksa 7 Saksi Termasuk...   0.000000  0.375000
# 296  Wali Kota Surakarta Tinjau Lokasi Rencana Pemb...   0.093750  0.220833
#
#     Sentiment_Type
# 0         Positive
# 1          Neutral
# 2         Positive
# 3         Negative
# 4         Negative
# 5         Positive
# 6          Neutral
# 7          Neutral
# 8         Positive
# 9         Negative
# 10         Neutral
# 11        Positive
# 12        Negative
# 13         Neutral
# 14         Neutral
# 15         Neutral
# 16        Negative
# 17         Neutral
# 18        Positive
# 19        Negative
# 20        Positive
# 21        Negative
# 22        Negative
# 23         Neutral
# 24        Negative
# 25         Neutral
# 26        Positive
# 27        Positive
# 28        Positive
# 29         Neutral
# ..             ...
# 267        Neutral
# 268        Neutral
# 269       Positive
# 270       Positive
# 271       Positive
# 272       Positive
# 273       Positive
# 274       Negative
# 275       Positive
# 276        Neutral
# 277       Negative
# 278       Positive
# 279       Positive
# 280        Neutral
# 281       Positive
# 282       Negative
# 283        Neutral
# 284        Neutral
# 285        Neutral
# 286       Negative
# 287       Negative
# 288       Negative
# 289       Positive
# 290        Neutral
# 291        Neutral
# 292       Positive
# 293       Positive
# 294        Neutral
# 295        Neutral
# 296       Positive
#
# [297 rows x 4 columns]
