# %%
import csv
import pandas as pd
import numpy as np
import nltk
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
import re
import seaborn as sns
import matplotlib.pyplot as plt
import base64
import string
from collections import Counter
from nltk.tokenize import word_tokenize
from textblob import TextBlob
from wordcloud import WordCloud
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words

# %%
train = pd.read_csv('merdekacom.csv', encoding= 'utf8', sep=',')

# %%
train = train[['Image_alt']]

# %%
train = train.rename(columns = {'Image_alt':'NewsTitle'})

# %%
train
# Out:
#                                              NewsTitle
# 0    Menteri PUPR Tunggu Gubernur Sulawesi Tengah B...
# 1    Menteri Basuki Belum Terima Laporan Kerusakan ...
# 2    Wapres JK Minta Menteri PUPR Buat Standarisasi...
# 3    Suap Proyek di Kementerian PUPR, KPK Periksa M...
# 4    Cegah Banjir, Kementerian PUPR Normalisasi Sun...
# 5    KPK Periksa 2 Saksi Terkait Kasus Suap Proyek ...
# 6    Hadapi Potensi Bencana Tsunami, PUPR Dorong Pe...
# 7    Pertama Kali, Program Satu Juta Rumah Capai Ta...
# 8    KPK Periksa Kepala Satuan Kerja SPAM Terkait Suap
# 9    Menteri Basuki: Tol Trans Jawa Dukung Peningka...
# 10   Jokowi: Pemerintah Rehabilitasi 3 Juta Hektare...
# 11   Kementerian PUPR Ganti Pejabat yang Kena OTT K...
# 12   2019, Infrastruktur Kerakyatan Tetap Jadi Prio...
# 13   Ini Jumlah Uang Sitaan KPK Hasil OTT Pejabat K...
# 14   Menteri PUPR Sebut Kantor Digeledah KPK Satker...
# 15   Menteri Basuki Duga OTT Kementerian PUPR Buntu...
# 16   KPK Duga Suap Proyek Air Daerah Bencana di Kem...
# 17   Anak Buah Kena OTT, Menteri PUPR Tunggu Penjel...
# 18   Irjen Kementerian PUPR Datangi KPK Konfirmasi ...
# 19   OTT Kementerian PUPR, KPK Sita Rp 500 Juta, SG...
# 20   OTT Kementerian PUPR Terkait Proyek Penyediaan...
# 21   OTT Pejabat Kementerian PUPR Diduga Terkait Pr...
# 22   OTT Pejabat Kementerian PUPR, KPK Tangkap 20 O...
# 23   OTT Pejabat Kementerian PUPR, KPK Amankan 4 Or...
# 24     KPK Dikabarkan Tangkap Pejabat Kementerian PUPR
# 25   PUPR: Ada Sekitar 600 Rumah di Banten dan Lamp...
# 26   Flyover Cengkareng Bukan Retak, Pemerintah Bil...
# 27   Kabar Jalan Tol Salatiga-Kartasura Ambrol Hoak...
# 28   Cetak Tenaga Kerja Terampil, Kementerian PU-PR...
# 29   PUPR Distribusikan 4.000 Liter Air Bersih ke P...
# ..                                                 ...
# 130  Kementerian PUPR apresiasi insan pendukung keb...
# 131  Kadin NTB buka toko bahan bangunan permudah ma...
# 132  Jurus PUPR kebut pembangunan rumah korban gemp...
# 133  Menteri Basuki manfaatkan teknologi hidrologi ...
# 134  Menteri Basuki siap contek Korea Selatan dalam...
# 135  Menteri Basuki ingin ahli teknik hidraulik bua...
# 136  Jalan aspal dibangun, transportasi di Kabupate...
# 137  Kementerian PU-PR bangunkan jalan masyarakat p...
# 138  Jalan perbatasan Kalimantan sepanjang 1.070 Km...
# 139  Bertemu Menteri PUPR, Wagub NTB minta tambahan...
# 140  Pemerintah hadiahi rumah untuk atlet peraih em...
# 141  Pemerintah bakal sediakan bahan bangunan untuk...
# 142  Pemerintah kebut pembangunan fasilitas umum da...
# 143  Pemerintah beri Rp 50 juta ke tiap KK, perbaik...
# 144  PUPR kirim 198 CPNS dan 178 insinyur bantu war...
# 145  Selain uang Rp 1,5 miliar, atlet peraih medali...
# 146  Jadikan Manahan SUGBK mini, Kemen PUPR siapkan...
# 147  Ini aksi tanggap darurat Kementerian PUPR tang...
# 148  Pemerintah bakal gandeng mahasiswa perbaiki in...
# 149  PUPR: Fasilitas publik Lombok akan berfungsi k...
# 150  Menteri Basuki: Pembangunan infrastruktur demi...
# 151  Ini rahasia Menteri Basuki dalam penciptaan ba...
# 152  Korban gempa Lombok dibebaskan sementara dari ...
# 153  Beli rumah subsidi, masyarakat berpenghasilan ...
# 154  Menteri Basuki: RI perlu cara 'rock and roll' ...
# 155  Per 28 Agustus, tarif tol akses Cikarang Dry P...
# 156  Kementerian PU-PR bangun 582.638 unit rumah mu...
# 157  Menteri Basuki ajak Kadin bangun rumah tahan g...
# 158  Konektivitas infrastruktur turunkan biaya logi...
# 159  Ketimpangan jumlah penduduk dan SDA jadi tanta...
#
# [160 rows x 1 columns]

# %%
tags_lower = train['NewsTitle'].str.lower().str.cat(sep=' ')

# %%
tags_remove_pun = re.sub('[^A-Za-z]+', ' ', tags_lower)

# %%
stop_words = list(get_stop_words('id'))

# %%
nltk_words = list(stopwords.words('indonesian'))

# %%
stop_words.extend(nltk_words)

# %%
word_tokens_tags = word_tokenize(tags_remove_pun)

# %%
filtered_sentence_tags = [w_tags for w_tags in word_tokens_tags if not w_tags in stop_words]

# %%
filtered_sentence_tags = []

# %%
for w_tags in word_tokens_tags:
    if w_tags not in stop_words:
        filtered_sentence_tags.append(w_tags)

# %%
without_single_chr_tags = [word_tags for word_tags in filtered_sentence_tags if len(word_tags) > 2]

# %%
cleaned_data_tags = [word_tags for word_tags in without_single_chr_tags if not word_tags.isnumeric()]

# %%
top_N = 10000

# %%
word_dist_tags = nltk.FreqDist(cleaned_data_tags)
rslt_tags = pd.DataFrame(word_dist_tags.most_common(top_N),
                    columns=['Word', 'Frequency'])

# %%
plt.figure(figsize=(18,10))
sns.set_style("whitegrid")
plt.title('Merdeka.com Topics')

ax = sns.barplot(x="Word",y="Frequency", data=rslt_tags.head(10))

rects = ax.patches

# For each bar: Place a label
for rect in rects:
    # Get X and Y placement of label from rect.
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width() / 2

    # Number of points between bar and label. Change to your liking.
    space = 5
    # Vertical alignment for positive values
    va = 'bottom'

    # If value of bar is negative: Place label below bar
    if y_value < 0:
        # Invert space to place label below
        space *= -1
        # Vertically align label at top
        va = 'top'

    # Use Y value as label and format number with one decimal place
    label = "{:.1f}".format(y_value)

    # Create annotation
    plt.annotate(
        label,                      # Use `label` as label
        (x_value, y_value),         # Place label at end of the bar
        xytext=(0, space),          # Vertically shift label by `space`
        textcoords="offset points", # Interpret `xytext` as offset in points
        ha='center',                # Horizontally center label
        va=va)                      # Vertically align label differently for
                                    # positive and negative values.

# %%
bloblist_desc = list()

train_descr_str=train['NewsTitle'].astype(str)
for row in train_descr_str:
    blob = TextBlob(row)
    an = blob.translate(from_lang='id', to='en')
    bloblist_desc.append((row,an.sentiment.polarity, an.sentiment.subjectivity))
    train_polarity_desc = pd.DataFrame(bloblist_desc, columns = ['sentence','sentiment','polarity'])

# %%
def f(train_polarity_desc):
    if train_polarity_desc['sentiment'] > 0:
        val = "Positive"
    elif train_polarity_desc['sentiment'] == 0:
        val = "Neutral"
    else:
        val = "Negative"
    return val

train_polarity_desc['Sentiment_Type'] = train_polarity_desc.apply(f, axis=1)

plt.figure(figsize=(5,10))
sns.set_style("whitegrid")
plt.title('Merdekacom Sentiment')
ax = sns.countplot(x="Sentiment_Type", data=train_polarity_desc, palette=["C0", "k", "C1"])

# %%
train_polarity_desc
# Out:
#                                               sentence  sentiment  polarity  \
# 0    Menteri PUPR Tunggu Gubernur Sulawesi Tengah B...   0.000000  0.250000
# 1    Menteri Basuki Belum Terima Laporan Kerusakan ...  -0.125000  0.375000
# 2    Wapres JK Minta Menteri PUPR Buat Standarisasi...   0.000000  0.000000
# 3    Suap Proyek di Kementerian PUPR, KPK Periksa M...   0.025000  0.250000
# 4    Cegah Banjir, Kementerian PUPR Normalisasi Sun...   0.000000  0.000000
# 5    KPK Periksa 2 Saksi Terkait Kasus Suap Proyek ...   0.000000  0.000000
# 6    Hadapi Potensi Bencana Tsunami, PUPR Dorong Pe...   0.000000  1.000000
# 7    Pertama Kali, Program Satu Juta Rumah Capai Ta...   0.250000  0.333333
# 8    KPK Periksa Kepala Satuan Kerja SPAM Terkait Suap   0.000000  0.000000
# 9    Menteri Basuki: Tol Trans Jawa Dukung Peningka...   0.000000  0.000000
# 10   Jokowi: Pemerintah Rehabilitasi 3 Juta Hektare...   0.400000  0.500000
# 11   Kementerian PUPR Ganti Pejabat yang Kena OTT K...   0.000000  0.400000
# 12   2019, Infrastruktur Kerakyatan Tetap Jadi Prio...   0.000000  0.000000
# 13   Ini Jumlah Uang Sitaan KPK Hasil OTT Pejabat K...   0.000000  0.000000
# 14   Menteri PUPR Sebut Kantor Digeledah KPK Satker...   0.000000  0.000000
# 15   Menteri Basuki Duga OTT Kementerian PUPR Buntu...  -0.100000  0.100000
# 16   KPK Duga Suap Proyek Air Daerah Bencana di Kem...   0.075000  0.216667
# 17   Anak Buah Kena OTT, Menteri PUPR Tunggu Penjel...   0.000000  0.000000
# 18   Irjen Kementerian PUPR Datangi KPK Konfirmasi ...   0.050000  0.500000
# 19   OTT Kementerian PUPR, KPK Sita Rp 500 Juta, SG...  -0.200000  0.100000
# 20   OTT Kementerian PUPR Terkait Proyek Penyediaan...   0.000000  0.400000
# 21   OTT Pejabat Kementerian PUPR Diduga Terkait Pr...   0.000000  0.233333
# 22   OTT Pejabat Kementerian PUPR, KPK Tangkap 20 O...   0.000000  0.000000
# 23   OTT Pejabat Kementerian PUPR, KPK Amankan 4 Or...   0.000000  0.000000
# 24     KPK Dikabarkan Tangkap Pejabat Kementerian PUPR   0.000000  0.000000
# 25   PUPR: Ada Sekitar 600 Rumah di Banten dan Lamp...   0.000000  0.000000
# 26   Flyover Cengkareng Bukan Retak, Pemerintah Bil...   0.000000  0.000000
# 27   Kabar Jalan Tol Salatiga-Kartasura Ambrol Hoak...   0.000000  0.000000
# 28   Cetak Tenaga Kerja Terampil, Kementerian PU-PR...   0.250000  0.283333
# 29   PUPR Distribusikan 4.000 Liter Air Bersih ke P...   0.366667  0.700000
# ..                                                 ...        ...       ...
# 130  Kementerian PUPR apresiasi insan pendukung keb...   0.150000  0.000000
# 131  Kadin NTB buka toko bahan bangunan permudah ma...   0.000000  0.000000
# 132  Jurus PUPR kebut pembangunan rumah korban gemp...   0.000000  0.000000
# 133  Menteri Basuki manfaatkan teknologi hidrologi ...   0.000000  0.000000
# 134  Menteri Basuki siap contek Korea Selatan dalam...   0.200000  0.500000
# 135  Menteri Basuki ingin ahli teknik hidraulik bua...   0.200000  0.100000
# 136  Jalan aspal dibangun, transportasi di Kabupate...   0.000000  0.000000
# 137  Kementerian PU-PR bangunkan jalan masyarakat p...   0.000000  0.044444
# 138  Jalan perbatasan Kalimantan sepanjang 1.070 Km...   0.000000  0.000000
# 139  Bertemu Menteri PUPR, Wagub NTB minta tambahan...  -0.200000  0.500000
# 140  Pemerintah hadiahi rumah untuk atlet peraih em...   0.000000  0.000000
# 141  Pemerintah bakal sediakan bahan bangunan untuk...   0.000000  0.000000
# 142  Pemerintah kebut pembangunan fasilitas umum da...   0.100000  0.083333
# 143  Pemerintah beri Rp 50 juta ke tiap KK, perbaik...   0.000000  0.000000
# 144  PUPR kirim 198 CPNS dan 178 insinyur bantu war...   0.000000  0.000000
# 145  Selain uang Rp 1,5 miliar, atlet peraih medali...   0.000000  0.000000
# 146  Jadikan Manahan SUGBK mini, Kemen PUPR siapkan...   0.000000  0.000000
# 147  Ini aksi tanggap darurat Kementerian PUPR tang...   0.100000  0.100000
# 148  Pemerintah bakal gandeng mahasiswa perbaiki in...   0.000000  0.000000
# 149  PUPR: Fasilitas publik Lombok akan berfungsi k...   0.000000  0.066667
# 150  Menteri Basuki: Pembangunan infrastruktur demi...   0.000000  0.000000
# 151  Ini rahasia Menteri Basuki dalam penciptaan ba...   0.050000  0.600000
# 152  Korban gempa Lombok dibebaskan sementara dari ...   0.000000  0.000000
# 153  Beli rumah subsidi, masyarakat berpenghasilan ...   0.000000  0.000000
# 154  Menteri Basuki: RI perlu cara 'rock and roll' ...   0.000000  0.000000
# 155  Per 28 Agustus, tarif tol akses Cikarang Dry P...  -0.066667  0.600000
# 156  Kementerian PU-PR bangun 582.638 unit rumah mu...   0.000000  0.000000
# 157  Menteri Basuki ajak Kadin bangun rumah tahan g...   0.000000  0.000000
# 158  Konektivitas infrastruktur turunkan biaya logi...   0.000000  0.000000
# 159  Ketimpangan jumlah penduduk dan SDA jadi tanta...   0.100000  0.400000
#
#     Sentiment_Type
# 0          Neutral
# 1         Negative
# 2          Neutral
# 3         Positive
# 4          Neutral
# 5          Neutral
# 6          Neutral
# 7         Positive
# 8          Neutral
# 9          Neutral
# 10        Positive
# 11         Neutral
# 12         Neutral
# 13         Neutral
# 14         Neutral
# 15        Negative
# 16        Positive
# 17         Neutral
# 18        Positive
# 19        Negative
# 20         Neutral
# 21         Neutral
# 22         Neutral
# 23         Neutral
# 24         Neutral
# 25         Neutral
# 26         Neutral
# 27         Neutral
# 28        Positive
# 29        Positive
# ..             ...
# 130       Positive
# 131        Neutral
# 132        Neutral
# 133        Neutral
# 134       Positive
# 135       Positive
# 136        Neutral
# 137        Neutral
# 138        Neutral
# 139       Negative
# 140        Neutral
# 141        Neutral
# 142       Positive
# 143        Neutral
# 144        Neutral
# 145        Neutral
# 146        Neutral
# 147       Positive
# 148        Neutral
# 149        Neutral
# 150        Neutral
# 151       Positive
# 152        Neutral
# 153        Neutral
# 154        Neutral
# 155       Negative
# 156        Neutral
# 157        Neutral
# 158        Neutral
# 159       Positive
#
# [160 rows x 4 columns]
